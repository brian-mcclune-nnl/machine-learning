# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %%
df = pd.read_csv('data/iris.data', header=None)

# %%
df.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
df.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## Iris data from Seaborn

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.groupby('species').size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %% [markdown]
# ## Visualization

# %%
sns.pairplot(iris, hue='species', size=3, aspect=1)

# %%
iris.hist(edgecolor='black', linewidth=1.2, figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002953656CE50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029536574BB0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000029536565D60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000295355D6880>]],
#       dtype=object)

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
sns.violinplot(x='species', y='sepal_length', data=iris)
plt.subplot(2, 2, 2)
sns.violinplot(x='species', y='sepal_width', data=iris)
plt.subplot(2, 2, 3)
sns.violinplot(x='species', y='petal_length', data=iris)
plt.subplot(2, 2, 4)
sns.violinplot(x='species', y='petal_width', data=iris)

# %%
iris.boxplot(by='species', figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029538FBEBB0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002953906AB20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000295391A78E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000295393B8EE0>]],
#       dtype=object)

# %%
pd.plotting.scatter_matrix(iris, figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000295394F01F0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029538DAF3A0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029538CC6490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029538D89340>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000029539542880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029538D34910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029538D34A00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000295394E2550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002953939FC40>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000295391AA550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002953906A970>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029538FBA430>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002953951BC10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000295393C7B50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002953939AE20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000029539052340>]],
#       dtype=object)

# %%
sns.pairplot(iris, hue='species', diag_kind='kde')
